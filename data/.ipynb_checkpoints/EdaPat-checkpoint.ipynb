# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df = df.drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
dup = df.loc[df.duplicated() == True]
dup.head()
# Out:
#      work_year experience_level employment_type       job_title  salary  \
# 217       2021               MI              FT  Data Scientist   76760
# 256       2021               MI              FT   Data Engineer  200000
# 331       2022               SE              FT    Data Analyst   90320
# 332       2022               SE              FT    Data Analyst  112900
# 333       2022               SE              FT    Data Analyst   90320
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 217             EUR          90734                 DE            50
# 256             USD         200000                 US           100
# 331             USD          90320                 US           100
# 332             USD         112900                 US           100
# 333             USD          90320                 US           100
#
#     company_location company_size
# 217               DE            L
# 256               US            L
# ...

# %%
numcol = df[["experience_level","employment_type","job_title","salary_currency","employee_residence","company_location","company_size"]]

# %%
numcol
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     salary_currency employee_residence company_location company_size
# 0               EUR                 DE               DE            L
# ...

# %%
numcat = df[['work_year','salary','salary_in_usd','remote_ratio']]

# %%
len(df)
# Out:
# 607

# %%
len(numcat)&len(numcol)
# Out:
# 607

# %%
dfs = df.sort_values(by = 'salary_currency')

# %%
dfs
# Out:
#      work_year experience_level employment_type                  job_title  \
# 505       2022               EN              FT             Data Scientist
# 503       2022               MI              FT  Machine Learning Engineer
# 205       2021               MI              FT             Data Scientist
# 271       2021               SE              FT   Computer Vision Engineer
# 511       2022               MI              FT      Business Data Analyst
# ..         ...              ...             ...                        ...
# 276       2021               EN              FT             Data Scientist
# 275       2021               EN              FT             Data Scientist
# 273       2021               EN              FT  Machine Learning Engineer
# 267       2021               MI              FT              Data Engineer
# 606       2022               MI              FT               AI Scientist
#
# ...

# %%
jobs = df['job_title'].value_counts()
jobs
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
exp = df['experience_level'].value_counts()
exp
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
sns.histplot(data = df, y = jobs.head(10), legend = True, bins = 30)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='job_title'>

# %%
sns.histplot(data = df, x = jobs, kde = True, bins = 30)
# Out:
# <AxesSubplot:xlabel='job_title', ylabel='Count'>

# %%
jobs
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
dfe = jobs.loc[jobs > 7]

# %%
dfe
# Out:
# Data Scientist                143
# Data Engineer                 132
# Data Analyst                   97
# Machine Learning Engineer      41
# Research Scientist             16
# Data Science Manager           12
# Data Architect                 11
# Big Data Engineer               8
# Machine Learning Scientist      8
# Name: job_title, dtype: int64

# %%
df1 = df["job_title"].value_counts() > 7
df1
# Out:
# Data Scientist                               True
# Data Engineer                                True
# Data Analyst                                 True
# Machine Learning Engineer                    True
# Research Scientist                           True
# Data Science Manager                         True
# Data Architect                               True
# Big Data Engineer                            True
# Machine Learning Scientist                   True
# Principal Data Scientist                    False
# AI Scientist                                False
# Data Science Consultant                     False
# Director of Data Science                    False
# Data Analytics Manager                      False
# ML Engineer                                 False
# Computer Vision Engineer                    False
# BI Data Analyst                             False
# Lead Data Engineer                          False
# Data Engineering Manager                    False
# ...

# %%
dfa = df1[df1 == True]
dfa
# Out:
# Data Scientist                True
# Data Engineer                 True
# Data Analyst                  True
# Machine Learning Engineer     True
# Research Scientist            True
# Data Science Manager          True
# Data Architect                True
# Big Data Engineer             True
# Machine Learning Scientist    True
# Name: job_title, dtype: bool

# %%
sns.boxplot(data = df, y = 'salary_in_usd', x = 'company_size')
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='salary_in_usd'>

# %%
# On constate que ce sont les entreprises de taille moyenne qui ont on salaire moyen le plus élévé
# Les grandes entreprises ont les salaires les plus élévés (tant en quartile qu'outliers)

# %%
df['employment_type'].value_counts()
# Out:
# FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %%
exp
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
expe = df["experience_level"].apply(lambda x:
                                            1 if x == "SE"
                                            else 2 if x == "MI"
                                            else 3 if x == "EN"
                                            else 4 if x == "EX"
                                            else "NaN")

# %%
Exp = expe.value_counts()

# %%
sns.countplot(data=df, y = df['job_title'].head(50), hue= expe)
# Out:
# <AxesSubplot:xlabel='count', ylabel='job_title'>

# %%
df['job_title'].sort_values
# Out:
# <bound method Series.sort_values of 0                  Data Scientist
# 1      Machine Learning Scientist
# 2               Big Data Engineer
# 3            Product Data Analyst
# 4       Machine Learning Engineer
#                   ...
# 602                 Data Engineer
# 603                 Data Engineer
# 604                  Data Analyst
# 605                  Data Analyst
# 606                  AI Scientist
# Name: job_title, Length: 607, dtype: object>

# %%
df.work_year.value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
expe
# Out:
# 0      2
# 1      1
# 2      1
# 3      2
# 4      1
#       ..
# 602    1
# 603    1
# 604    1
# 605    1
# 606    2
# Name: experience_level, Length: 607, dtype: int64

# %%
sns.barplot(data = df, y = expe, x = df.company_location.head(10), ci = None)
# Out:
# <AxesSubplot:xlabel='company_location', ylabel='experience_level'>

# %%
df.company_location.value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
df.company_location.head(10)
# Out:
# 0    DE
# 1    JP
# 2    GB
# 3    HN
# 4    US
# 5    US
# 6    US
# 7    HU
# 8    US
# 9    NZ
# Name: company_location, dtype: object

# %%
land = df.company_location.groupby(by = df.company_location).head()
land.value_counts()
# Out:
# DE    5
# FR    5
# JP    5
# CA    5
# GR    5
# IN    5
# ES    5
# US    5
# GB    5
# NL    4
# AT    4
# PT    4
# PL    4
# LU    3
# PK    3
# BR    3
# AE    3
# MX    3
# AU    3
# TR    3
# DK    3
# IT    2
# CZ    2
# SI    2
# RU    2
# CH    2
# NG    2
# CN    2
# BE    2
# VN    1
# EE    1
# AS    1
# DZ    1
# MY    1
# MD    1
# KE    1
# SG    1
# CO    1
# IR    1
# CL    1
# MT    1
# IL    1
# UA    1
# IQ    1
# RO    1
# HR    1
# NZ    1
# HU    1
# HN    1
# IE    1
# Name: company_location, dtype: int64

# %%
sns.barplot(data = df, x = expe, y = land.head(), ci = None)
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='company_location'>

# %%
landia = df.company_location.value_counts().head()
landia
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# Name: company_location, dtype: int64

# %%
sns.barplot(data = df, y = expe, x = landia, ci = None)
# Out:
# <AxesSubplot:xlabel='company_location', ylabel='experience_level'>

# %%
df.company_location.groupby(by = df.remote_ratio).value_counts()
# Out:
# remote_ratio  company_location
# 0             US                  69
#               GB                  19
#               IN                   6
#               DE                   5
#               CA                   4
#                                   ..
# 100           MY                   1
#               PT                   1
#               SI                   1
#               TR                   1
#               UA                   1
# Name: company_location, Length: 84, dtype: int64

# %%
ratio = df[df["remote_ratio"] == 100]
ratio
# Out:
#      work_year experience_level employment_type              job_title  \
# 5         2020               EN              FT           Data Analyst
# 6         2020               SE              FT    Lead Data Scientist
# 8         2020               MI              FT  Business Data Analyst
# 13        2020               MI              FT      Lead Data Analyst
# 14        2020               MI              FT           Data Analyst
# ..         ...              ...             ...                    ...
# 599       2022               MI              FT         Data Scientist
# 602       2022               SE              FT          Data Engineer
# 603       2022               SE              FT          Data Engineer
# 605       2022               SE              FT           Data Analyst
# 606       2022               MI              FT           AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
xia = ratio.company_location.value_counts().head()
xia
# Out:
# US    266
# CA     19
# GB     17
# DE     12
# ES     12
# Name: company_location, dtype: int64

# %%
# ratio des pays faisant majoritairement du télétravail

# %%
xia.plot(kind = "pie", autopct = "%1.1f%%")
# Out:
# <AxesSubplot:ylabel='company_location'>

# %% [markdown]
# def barplot(variable, titre, xlabel: str, ylabel: str):
#     b = data.groupby([variable]).mean()
#     plt.figure(figsize=(15, 5))
#     sns.barplot(x=b["salary"], y=b.index, palette="viridis")
#     plt.title(titre)
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     return plt.show()

# %%
jobi = df.groupby(["job_title"]).head()
jobi
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 519       2022               SE              FT      Applied Data Scientist
# 523       2022               SE              FT         Data Analytics Lead
# 525       2022               SE              FT      Applied Data Scientist
# 560       2022               SE              FT          Analytics Engineer
# 561       2022               SE              FT          Analytics Engineer
#
# ...

# %%
jobi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 561
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           170 non-null    int64
#  1   experience_level    170 non-null    object
#  2   employment_type     170 non-null    object
#  3   job_title           170 non-null    object
#  4   salary              170 non-null    int64
#  5   salary_currency     170 non-null    object
#  6   salary_in_usd       170 non-null    int64
#  7   employee_residence  170 non-null    object
#  8   remote_ratio        170 non-null    int64
#  9   company_location    170 non-null    object
#  10  company_size        170 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 15.9+ KB

# %%
jobi.sort_values(by = 'salary_in_usd', ascending = False)
# Out:
#      work_year experience_level employment_type  \
# 252       2021               EX              FT
# 33        2020               MI              FT
# 97        2021               MI              FT
# 157       2021               MI              FT
# 225       2021               EX              CT
# ..         ...              ...             ...
# 38        2020               EN              FT
# 15        2020               MI              FT
# 21        2020               MI              FT
# 18        2020               EN              FT
# 77        2021               MI              PT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 33                   Research Scientist  450000             USD
# 97               Financial Data Analyst  450000             USD
# 157  Applied Machine Learning Scientist  423000             USD
# ...

# %%
sns.barplot(data = jobi, x = "salary_in_usd", y = "job_title", ci = None)
sns.set(rc={"figure.figsize":(50, 20)})

# %%
catplot = sns.catplot(data = df, 
                      kind = 'bar', 
                      x = 'salary_in_usd', 
                      y = 'job_title', 
                      hue = 'experience_level', 
                      palette = 'Paired', 
                      height = 30, 
                      aspect = 0.5,
                      ci = None)
catplot.set_axis_labels('Salaire', 'Job')
catplot.legend.set_title('experience_level')
plt.show()

# %%
def regroup_job(df):
    new_df = df.copy()
    replace_names = {'ML Engineer': ['Machine Learning Engineer', 'Machine Learning Scientist', 'ML Engineer', 
                                     'Applied Machine Learning Scientist', 'Machine Learning Developer', 
                                     'Machine Learning Infrastructure Engineer', 'Applied ML Engineer'],
                     'Data Scientist': ['Data Scientist', 'Research Scientist', 'AI Scientist', 'Data Science Consultant',
                                        'Computer Vision Engineer', 'Applied Data Scientist', 'Computer Vision Software Engineer',
                                        'Data Science Engineer', 'NLP Engineer', '3D Computer Vision Researcher', 
                                        'Staff Data Scientist'],
                     'Data Analytics Manager': ['Data Analytics Manager', 'Lead Data Analyst', 'Principal Data Analyst', 
                                               'Data Analytics Lead'],
                     'Machine Learning Manager': ['Lead Machine Learning Engineer', 'Head of Machine Learning', 
                                                  'Machine Learning Manager', 'Lead ML Engineer'],
                     'Data Engineer': ['Big Data Engineer', 'Analytics Engineer', 'Data Analytics Engineer', 'Data Data Engineer'],
                     'Data Analyst': ['BI Data Analyst', 'Product Data Analyst', 'Financial Data Analyst', 'Finance Data Analyst',
                                      'Marketing Data Analyst', 'Business Data Analyst', 'Data Specialist'],
                     'Data Science Manager': ['Principal Data Scientist', 'Director of Data Science', 'Head of Data Science', 
                                              'Head of Data'],
                     'Lead Data Engineer': ['Data Engineering Manager', 'Lead Data Scientist', 'Principal Data Engineer',
                                            'Director of Data Engineering'],
                     'Data Architect': ['ETL Developer', 'Cloud Data Engineer', 'Big Data Architect']
                    }

    for replace_name, name_list in replace_names.items():
        for name in name_list:
            new_df['job_title'] = new_df['job_title'].replace(name, replace_name)
    
    return new_df

# %%
new_df = regroup_job(df)

# %%
new_df['job_title'].value_counts()
# Out:
# Data Scientist              193
# Data Engineer               148
# Data Analyst                115
# ML Engineer                  65
# Data Science Manager         35
# Lead Data Engineer           19
# Data Architect               16
# Data Analytics Manager       13
# Machine Learning Manager      3
# Name: job_title, dtype: int64

# %%
# refaire des graphiques à partir d'ici

# %%
sns.boxplot(data = new_df, y = 'salary_in_usd', x = 'company_size')
# Out:
# <AxesSubplot:xlabel='company_size', ylabel='salary_in_usd'>

# %%
sns.countplot(data=new_df, y = new_df['job_title'].head(50), hue= expe)
# Out:
# <AxesSubplot:xlabel='count', ylabel='job_title'>

# %%
sns.barplot(data = new_df, y = expe, x = new_df.company_location.head(10), ci = None)
# Out:
# <AxesSubplot:xlabel='company_location', ylabel='experience_level'>

# %%
sns.barplot(data = new_df, x = expe, y = land.head(), ci = None)
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='company_location'>

# %%
sns.barplot(data = new_df, x = "salary_in_usd", y = "job_title", ci = None)
sns.set(rc={"figure.figsize":(50, 20)})

# %%
catplot = sns.catplot(data = new_df, 
                      kind = 'bar', 
                      x = 'salary_in_usd', 
                      y = 'job_title', 
                      hue = 'experience_level', 
                      palette = 'Paired', 
                      height = 10, 
                      aspect = 1,
                      ci = None)
catplot.set_axis_labels('Salaire', 'Job')
catplot.legend.set_title('experience_level')
plt.show()
